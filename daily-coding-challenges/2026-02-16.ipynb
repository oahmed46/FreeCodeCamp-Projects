# %% [markdown]
# https://www.freecodecamp.org/learn/daily-coding-challenge/2026-02-16

# %% [markdown]
# 2026 Winter Games Day 11: Ice Hockey
# Given an array of 6 ice hockey teams and their records after the round robin games, determine the match-ups for the semi-final round.
#
# Each array item will have a team and their record in the format "TEAM: W-OTW-OTL-L". Where:
# "W" is the number of wins in regulation, worth 3 points each
# "OTW" is the number of overtime wins, worth 2 points each
# "OTL" is the number of overtime losses, worth 1 point each
# "L" is the number of losses, worth 0 points each
# For example, "FIN: 2-2-1-0" would have 11 points after adding up their record.
#
# Find the total number of points for each team and return "The semi-final games will be (1st) vs (4th) and (2nd) vs (3rd).". For example, "The semi-final games will be FIN vs SWE and CAN vs USA."

# %%
def get_semifinal_matchups(teams):
    team_scores = []
    for team in teams:
        name, record = team.split(": ")
        win, overtime_win, overtime_loss, loss = record.split("-")
        points = int(win)*3 + int(overtime_win)*2 + int(overtime_loss)
        team_scores.append((name,points))

    team_scores = sorted(team_scores, key=lambda x: x[1], reverse=True)

    
    first = team_scores[0][0]
    second = team_scores[1][0]
    third = team_scores[2][0]
    fourth = team_scores[3][0]

    return f"The semi-final games will be {first} vs {fourth} and {second} vs {third}."

# %%
get_semifinal_matchups(["CAN: 2-2-0-1", "FIN: 2-2-1-0", "GER: 1-0-1-3", "SUI: 0-1-3-1", "SWE: 1-1-2-1", "USA: 2-1-0-2"]) #"The semi-final games will be FIN vs SWE and CAN vs USA."
# Out:
# 'The semi-final games will be FIN vs SWE and CAN vs USA.'

# %%
get_semifinal_matchups(["CAN: 2-1-1-1", "CZE: 1-1-1-2", "FIN: 1-2-1-1", "NOR: 0-1-1-3", "SLO: 1-0-1-3", "USA: 5-0-0-0"]) #"The semi-final games will be USA vs CZE and CAN vs FIN."
# Out:
# 'The semi-final games will be USA vs CZE and CAN vs FIN.'

# %%
get_semifinal_matchups(["CAN: 3-2-0-0", "CZE: 2-1-2-0", "LAT: 0-0-1-4", "ITA: 1-1-1-2", "DEN: 1-0-0-4", "USA: 3-1-1-0"]) #"The semi-final games will be CAN vs ITA and USA vs CZE."
# Out:
# 'The semi-final games will be CAN vs ITA and USA vs CZE.'

# %%
get_semifinal_matchups(["AUT: 2-2-1-0", "DEN: 1-0-0-4", "ITA: 1-1-1-2", "JPN: 3-2-0-0", "KOR: 2-1-2-0", "LAT: 0-0-1-4"]) #"The semi-final games will be JPN vs ITA and AUT vs KOR."
# Out:
# 'The semi-final games will be JPN vs ITA and AUT vs KOR.'
