# %% [markdown]
# https://www.freecodecamp.org/learn/daily-coding-challenge/2026-05-28

# %% [markdown]
# FizzBuzz Count
# Given a start and end number, count the number of fizz and buzz appearances in the range (inclusive).
#
# Numbers divisible by 3 count as a fizz.
# Numbers divisible by 5 count as a buzz.
# Numbers divisible by both 3 and 5 count as both a fizz and a buzz.
# Return an object or dictionary with the counts in the format: { fizz, buzz }.

# %%
def fizz_buzz_count(start, end):
    fizzbuzz = {"fizz": 0,"buzz": 0}
    for i in range(start,end+1):
        if i%3 == 0:
            fizzbuzz["fizz"] += 1
        if i%5 == 0:
            fizzbuzz["buzz"] += 1
    print(fizzbuzz)
    return fizzbuzz

# %%
fizz_buzz_count(1, 11) # {"fizz": 3, "buzz": 2}
# Out:
# {'fizz': 3, 'buzz': 2}
# {'fizz': 3, 'buzz': 2}

# %%
fizz_buzz_count(14, 41) # {"fizz": 9, "buzz": 6}
# Out:
# {'fizz': 9, 'buzz': 6}
# {'fizz': 9, 'buzz': 6}

# %%
fizz_buzz_count(24, 100) # {"fizz": 26, "buzz": 16}
# Out:
# {'fizz': 26, 'buzz': 16}
# {'fizz': 26, 'buzz': 16}

# %%
fizz_buzz_count(-635, -14) # {"fizz": 207, "buzz": 125}
# Out:
# {'fizz': 207, 'buzz': 125}
# {'fizz': 207, 'buzz': 125}

# %%
fizz_buzz_count(-5432, 6789) # {"fizz": 4074, "buzz": 2444}
# Out:
# {'fizz': 4074, 'buzz': 2444}
# {'fizz': 4074, 'buzz': 2444}
