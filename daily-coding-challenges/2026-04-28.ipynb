# %% [markdown]
# https://www.freecodecamp.org/learn/daily-coding-challenge/2026-04-28

# %% [markdown]
# Number Words
# Given an integer from 0 to 99, return its English word representation.
#
# 0 returns "zero".
# Numbers 1-19 have unique names ("one", "two", ..., "ten", "eleven", ..., "eighteen", "nineteen").
# Multiples of 10 from 20-90 have their own names ("twenty", "thirty", ..., "eighty", "ninety").
# Numbers 21-99 that are not multiples of 10 are written as two words joined by a hyphen. For example "forty-two" and "fifty-three".

# %%
def get_number_words(n):

    unique_values = list(range(1,20))
    unique_names = ["one","two","three","four","five","six","seven","eight",
    "nine","ten","eleven","twelve","thirteen","fourteen","fifteen",
    "sixteen","seventeen","eighteen","nineteen"]
    unique = dict(zip(unique_values,unique_names))

    multiples_values = list(range(2,10))
    multiples_names = ["twenty","thirty","fourty","fifty","sixty","seventy",
    "eighty","ninety"]
    multiples = dict(zip(multiples_values,multiples_names))

    if n == 0:
        return "zero"
    if n in unique:
        return unique[n]
    if n%10 == 0:
        return multiples[n//10]
    else:
        return multiples[n//10] + "-" + unique[n%10]

# %%
get_number_words(0) # "zero"
# Out:
# 'zero'

# %%
get_number_words(10) # "ten"
# Out:
# 'ten'

# %%
get_number_words(19) # "nineteen"
# Out:
# 'nineteen'

# %%
get_number_words(30) # "thirty"
# Out:
# 'thirty'

# %%
get_number_words(30) # "thirty"
# Out:
# 'thirty'

# %%
get_number_words(53) # "fifty-three"
# Out:
# 'fifty-three'

# %%
get_number_words(7) # "seven"
# Out:
# 'seven'

# %%
get_number_words(12) # "twelve"
# Out:
# 'twelve'

# %%
get_number_words(60) # "sixty"
# Out:
# 'sixty'

# %%
get_number_words(67) # "sixty-seven"
# Out:
# 'sixty-seven'

# %%
get_number_words(98) # "ninety-eight"
# Out:
# 'ninety-eight'
